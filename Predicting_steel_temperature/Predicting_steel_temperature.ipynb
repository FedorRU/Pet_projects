# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Данные-об-электродах" data-toc-modified-id="Данные-об-электродах-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Данные об электродах</a></span></li><li><span><a href="#Данные-о-подаче-сыпучих-материалов" data-toc-modified-id="Данные-о-подаче-сыпучих-материалов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Данные о подаче сыпучих материалов</a></span></li><li><span><a href="#Данные-о--проволочных-материалах" data-toc-modified-id="Данные-о--проволочных-материалах-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Данные о  проволочных материалах</a></span></li><li><span><a href="#Данные-о-продувке-сплава-газом" data-toc-modified-id="Данные-о-продувке-сплава-газом-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Данные о продувке сплава газом</a></span></li><li><span><a href="#Результаты-изменения-температуры" data-toc-modified-id="Результаты-изменения-температуры-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Результаты изменения температуры</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков-и-выбросов" data-toc-modified-id="Обработка-пропусков-и-выбросов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков и выбросов</a></span></li><li><span><a href="#Создание-признаков" data-toc-modified-id="Создание-признаков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Создание признаков</a></span></li><li><span><a href="#Проверка-мультиколлинеарности" data-toc-modified-id="Проверка-мультиколлинеарности-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Проверка мультиколлинеарности</a></span></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ моделей</a></span><ul class="toc-item"><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Тестирование</a></span></li></ul></li><li><span><a href="#Отчет" data-toc-modified-id="Отчет-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Отчет</a></span></li></ul></div>

# %% [markdown]
# # Определение температуры стали

# %% [markdown]
# **Условие задачи**
#
# Чтобы оптимизировать производственные расходы, металлургический комбинат ООО «Так закаляем сталь» решил уменьшить потребление электроэнергии на этапе обработки стали. Вам предстоит построить модель, которая предскажет температуру стали.
#
# **Описание этапа обработки**
#
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# Из сплава выводится сера (десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (англ. tribe, «масса»).
#
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.
#
# Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (англ. slab, «плита»).

# %% [markdown]
# **Описание данных**
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `data_arc.csv` — данные об электродах;
# - `data_bulk.csv` — данные о подаче сыпучих материалов (объём);
# - `data_bulk_time.csv` *—* данные о подаче сыпучих материалов (время);
# - `data_gas.csv` — данные о продувке сплава газом;
# - `data_temp.csv` — результаты измерения температуры;
# - `data_wire.csv` — данные о проволочных материалах (объём);
# - `data_wire_time.csv` — данные о проволочных материалах (время).
#
# Во всех файлах столбец `key` содержит номер партии. В файлах может быть несколько строк с одинаковым значением `key`: они соответствуют разным итерациям обработки.

# %% [markdown]
# **План работы**
#
# _1_. Анализ данных
#
# _2_. Подготовка данных
# -  Обработка пропусков и выбросов
# - Составление единой таблицы
# - Создание признаков
#
# _3_. Анализ моделей
# - Разбиение данных на обучающую и тестовую выборки
# - Обучение и поиск гиперпарметров моделей
# - Оценка моделей
# - Анализ важности факторов
#
# _4_. Отчет о проделанной работе

# %% [markdown]
# ## Анализ данных

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import ydata_profiling
from ydata_profiling import ProfileReport
import glob
import scipy.stats as st
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from lightgbm import LGBMRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error
import time
sns.set(style='darkgrid', font_scale=1.4)
RANDOM_STATE = 70423
PATH='/Users/fedor/Desktop/Yandex/final_steel/'

# %%
try:
    data_arc = pd.read_csv(PATH + 'data_arc.csv')
    data_bulk = pd.read_csv(PATH + 'data_bulk.csv')
    data_bulk_time = pd.read_csv(PATH + 'data_bulk_time.csv')
    data_gas = pd.read_csv(PATH + 'data_gas.csv')
    data_temp = pd.read_csv(PATH + 'data_temp.csv')
    data_wire = pd.read_csv(PATH + 'data_wire.csv')
    data_wire_time = pd.read_csv(PATH + 'data_wire_time.csv')
    
except:
    data_arc = pd.read_csv('/datasets/final_steel/data_arc.csv')
    data_bulk = pd.read_csv('/datasets/final_steel/data_bulk.csv')
    data_bulk_time = pd.read_csv('/datasets/final_steel/data_bulk_time.csv')
    data_gas = pd.read_csv('/datasets/final_steel/data_gas.csv')
    data_temp = pd.read_csv('/datasets/final_steel/data_temp.csv')
    data_wire = pd.read_csv('/datasets/final_steel/data_wire.csv')
    data_wire_time = pd.read_csv('/datasets/final_steel/data_wire_time.csv')

# %% [markdown]
# ### Данные об электродах

# %%
data_arc.head()
# Out:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.976059
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.805607
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.744363
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           1.659363
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.692755
#
#    Реактивная мощность
# 0             0.687084
# 1             0.520285
# 2             0.498805
# 3             1.062669
# 4             0.414397

# %%
data_arc_report = data_arc.profile_report(minimal=False, progress_bar=True)
data_arc_report.to_file("data_arc_report.html")
data_arc_report
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.1.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-04-14 12:15:35.381604&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# - Пропусков и дубликатов в данных нет.
# - Всего 3241 партия. Максимальное количество итераций одной партии = 16
# - Высокая положительная корреляци между активной и реактивной мощностью.
# - В столбце "Реактивная мощность" присутсвует одно отрицательное значение.
# - Имеется небольшая скошенность в данных в столбцах "Активная мощность" и "Реактивная мощность".
#
# Следует изменить названия столбцов и типы данных, а так же исправить выбросы.

# %%
data_arc.columns = ['key', 'arc_heating_start', 'arc_heating_end', 'active_power', 'reactive_power']
data_arc['arc_heating_start'] = pd.to_datetime(data_arc['arc_heating_start'])
data_arc['arc_heating_end'] = pd.to_datetime(data_arc['arc_heating_end'])

# %%
data_arc.head(5)
# Out:
#    key   arc_heating_start     arc_heating_end  active_power  reactive_power
# 0    1 2019-05-03 11:02:14 2019-05-03 11:06:02      0.976059        0.687084
# 1    1 2019-05-03 11:07:28 2019-05-03 11:10:33      0.805607        0.520285
# 2    1 2019-05-03 11:11:44 2019-05-03 11:14:36      0.744363        0.498805
# 3    1 2019-05-03 11:18:14 2019-05-03 11:24:19      1.659363        1.062669
# 4    1 2019-05-03 11:26:09 2019-05-03 11:28:37      0.692755        0.414397

# %%
plt.figure(figsize=(20,6))
ax = sns.histplot(data_arc['key'].value_counts(), color='dodgerblue', bins=15)
ax.set_title('Распределение количества итераций в всех партиях')
ax.set(xlabel=' ', ylabel = 'Количество');

# %% [markdown]
# Чаще всего происходит пять итераций в одной партии.

# %%
data_arc[data_arc.key == data_arc[data_arc['reactive_power'] < 0].key.item()]
# Out:
#        key   arc_heating_start     arc_heating_end  active_power  \
# 9778  2116 2019-07-24 00:29:52 2019-07-24 00:31:54      0.433266
# 9779  2116 2019-07-24 00:35:50 2019-07-24 00:38:05      0.620265
# 9780  2116 2019-07-24 00:44:48 2019-07-24 00:46:37      0.495782
# 9781  2116 2019-07-24 00:51:51 2019-07-24 00:52:58      0.299368
#
#       reactive_power
# 9778        0.306141
# 9779        0.408352
# 9780     -715.504924
# 9781        0.198796

# %% [markdown]
# ### Данные о подаче сыпучих материалов

# %%
data_bulk.head()
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0

# %%
data_bulk_time.head()
# Out:
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaN    NaN    NaN  2019-05-03 11:21:30    NaN    NaN    NaN    NaN
# 1    2    NaN    NaN    NaN  2019-05-03 11:46:38    NaN    NaN    NaN    NaN
# 2    3    NaN    NaN    NaN  2019-05-03 12:31:06    NaN    NaN    NaN    NaN
# 3    4    NaN    NaN    NaN  2019-05-03 12:48:43    NaN    NaN    NaN    NaN
# 4    5    NaN    NaN    NaN  2019-05-03 13:18:50    NaN    NaN    NaN    NaN
#
#   Bulk 9 Bulk 10 Bulk 11              Bulk 12 Bulk 13              Bulk 14  \
# 0    NaN     NaN     NaN  2019-05-03 11:03:52     NaN  2019-05-03 11:03:52
# 1    NaN     NaN     NaN  2019-05-03 11:40:20     NaN  2019-05-03 11:40:20
# 2    NaN     NaN     NaN  2019-05-03 12:09:40     NaN  2019-05-03 12:09:40
# 3    NaN     NaN     NaN  2019-05-03 12:41:24     NaN  2019-05-03 12:41:24
# 4    NaN     NaN     NaN  2019-05-03 13:12:56     NaN  2019-05-03 13:12:56
#
#                Bulk 15
# 0  2019-05-03 11:03:52
# ...

# %% [markdown]
# Датасеты имеют одинаковую структуры в одном представленно время использования материала, в другом его количество

# %%
data_bulk.columns = data_bulk.columns.str.replace(' ', '_').str.lower()
data_bulk_time.columns = data_bulk_time.columns.str.replace(' ', '_').str.lower()

# %%
ax = sns.displot(data = data_bulk.isnull().melt(value_name="missing"),
    y="variable", hue="missing", color='dodgerblue', multiple="fill", aspect=1.25)
ax.set(xlabel=' ', ylabel = 'Материалы');

# %% [markdown]
# Материалы 1, 2, 5, 7, 8, 9, 10, 11, 13 используются в малом количестве партий. Возможно их следует удалить при обработке данных.
# Так же следует удалить пропуски, объединить обе таблицы и изменить тип данных в data_bulk_time.

# %% [markdown]
# ### Данные о  проволочных материалах

# %%
data_wire.head()
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
data_wire_time.head()
# Out:
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:11:41                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:46:10                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:13:47                  NaN    NaN    NaN    NaN    NaN
# 3    4  2019-05-03 12:48:05                  NaN    NaN    NaN    NaN    NaN
# 4    5  2019-05-03 13:18:15  2019-05-03 13:32:06    NaN    NaN    NaN    NaN
#
#   Wire 7 Wire 8 Wire 9
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# 2    NaN    NaN    NaN
# 3    NaN    NaN    NaN
# 4    NaN    NaN    NaN

# %%
data_wire.columns = data_wire.columns.str.replace(' ', '_').str.lower()
data_wire_time.columns = data_wire_time.columns.str.replace(' ', '_').str.lower()

# %%
data_wire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   wire_1  3055 non-null   float64
#  2   wire_2  1079 non-null   float64
#  3   wire_3  63 non-null     float64
#  4   wire_4  14 non-null     float64
#  5   wire_5  1 non-null      float64
#  6   wire_6  73 non-null     float64
#  7   wire_7  11 non-null     float64
#  8   wire_8  19 non-null     float64
#  9   wire_9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB

# %%
data_wire_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   wire_1  3055 non-null   object
#  2   wire_2  1079 non-null   object
#  3   wire_3  63 non-null     object
#  4   wire_4  14 non-null     object
#  5   wire_5  1 non-null      object
#  6   wire_6  73 non-null     object
#  7   wire_7  11 non-null     object
#  8   wire_8  19 non-null     object
#  9   wire_9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB

# %%
ax = sns.displot(data = data_wire.isnull().melt(value_name="missing"),
    y="variable", hue="missing", color='dodgerblue', multiple="fill", aspect=1.25)
ax.set(xlabel=' ', ylabel = 'Материалы');

# %% [markdown]
# Данные о проводах содержат аналогичную струтктуру, большое количество пропусков в проводах 3-9. Обработаем их позже.

# %% [markdown]
# ### Данные о продувке сплава газом

# %%
data_gas.head()
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
data_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB

# %%
data_gas.describe()
# Out:
#                key        Газ 1
# count  3239.000000  3239.000000
# mean   1621.861377    11.002062
# std     935.386334     6.220327
# min       1.000000     0.008399
# 25%     812.500000     7.043089
# 50%    1622.000000     9.836267
# 75%    2431.500000    13.769915
# max    3241.000000    77.995040

# %%
data_gas.columns = ['key', 'gas_1']

# %%
plt.figure(figsize=(20,10))
ax = sns.lineplot(data = data_gas, x='key', y='gas_1', color='dodgerblue')
ax.set(xlabel=' ', ylabel = 'Объем газа');

# %% [markdown]
# Средний объем используемого газа около 11. В некотрых местах присутствуют пики, хотя с точки зрения тезнологического процесса выбросами их назвать трудно. На каждую партию приходится одна продувка газом.

# %% [markdown]
# ### Результаты изменения температуры

# %%
data_temp.head(10)
# Out:
#    key         Время замера  Температура
# 0    1  2019-05-03 11:16:18       1571.0
# 1    1  2019-05-03 11:25:53       1604.0
# 2    1  2019-05-03 11:29:11       1618.0
# 3    1  2019-05-03 11:30:01       1601.0
# 4    1  2019-05-03 11:30:39       1613.0
# 5    2  2019-05-03 11:37:27       1581.0
# 6    2  2019-05-03 11:38:00       1577.0
# 7    2  2019-05-03 11:49:38       1589.0
# 8    2  2019-05-03 11:55:50       1604.0
# 9    2  2019-05-03 11:58:24       1608.0

# %%
data_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           15907 non-null  int64
#  1   Время замера  15907 non-null  object
#  2   Температура   13006 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.9+ KB

# %%
data_temp.columns = ['key', 'time', 'temperature']
data_temp['time'] = pd.to_datetime(data_temp['time'])

# %%
data_temp.describe()
# Out:
#                 key   temperature
# count  15907.000000  13006.000000
# mean    1607.880870   1591.840920
# std      942.212073     21.375851
# min        1.000000   1191.000000
# 25%      790.000000   1581.000000
# 50%     1618.000000   1591.000000
# 75%     2427.000000   1601.000000
# max     3241.000000   1705.000000

# %%
data_temp[data_temp['temperature'].isnull()]
# Out:
#         key                time  temperature
# 12268  2500 2019-08-06 03:24:43          NaN
# 12269  2500 2019-08-06 03:25:16          NaN
# 12270  2500 2019-08-06 03:28:21          NaN
# 12272  2501 2019-08-06 04:01:59          NaN
# 12273  2501 2019-08-06 04:14:35          NaN
# ...     ...                 ...          ...
# 15901  3240 2019-09-01 03:35:16          NaN
# 15903  3241 2019-09-01 04:16:12          NaN
# 15904  3241 2019-09-01 04:22:39          NaN
# 15905  3241 2019-09-01 04:33:42          NaN
# 15906  3241 2019-09-01 04:38:08          NaN
#
# [2901 rows x 3 columns]

# %%
data_temp[data_temp['temperature'].isnull()].key.value_counts()
# Out:
# 2567    12
# 2770    12
# 2564    11
# 2916    11
# 2684    10
#         ..
# 3165     1
# 2620     1
# 3109     1
# 2862     1
# 3047     1
# Name: key, Length: 739, dtype: int64

# %%
plt.figure(figsize=(20,8))
fig = sns.kdeplot(data_temp['key'].value_counts(), color='dodgerblue', label='Замер температуры')
sns.kdeplot(data_arc['key'].value_counts(), color='deeppink', label='Электроды')
fig.set_title('Распределение количества итераций')
fig.set(xlabel='Номер партии', ylabel = 'Доля')
plt.legend();

# %% [markdown]
# Рапсределения количества итераций в партии не совпадет в таблицах об электродах и замерах температуры. В данных о температуре 2901 пропуск. В 739 партиях находятся пропуски. Возможно, стоит удалить данные о всех партиях, где присутсвуют пропуски в целевом признаке.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Обработка пропусков и выбросов

# %%
equal_count = (data_temp.groupby(by='key').count()['time'] == data_temp.groupby(by='key').count()['temperature'])\
.to_frame().index.values.tolist()

# %%
data_temp = data_temp[data_temp['key'].isin(equal_count)]

# %% [markdown]
# Оставим только те партии, где количество замеров температуры совпадает с количеством значений.

# %%
bulk_list = ['bulk_1', 'bulk_2', 'bulk_5', 'bulk_7', 'bulk_8',
                                             'bulk_9', 'bulk_10', 'bulk_11', 'bulk_13']
wire_list = ['wire_3', 'wire_4', 'wire_5', 'wire_6', 'wire_7', 'wire_8', 'wire_9']

# %%
def sum_time(data, column_list):
    data_new = data.copy()
    data_new[data_new.columns[1:]] = data_new[data_new.columns[1:]].apply(pd.to_datetime, errors='coerce')
    data_small = data_new[~data_new[column_list].isnull().all(axis=1)][column_list]
    data_small[column_list] = data_small[column_list].apply(pd.to_datetime, errors='coerce')
    data_new['sum'] = data_small.max(axis=1)
    data_new.drop(column_list, axis=1, inplace=True)
    return data_new
def sum_mat(data, column_list):
    data_new = data.copy()
    data_new['sum'] = data_new[column_list].sum(axis=1)
    data_new.drop(column_list, axis=1, inplace=True)
    return data_new

# %%
data_bulk_new = sum_mat(data_bulk, bulk_list)
data_bulk_time_new = sum_time(data_bulk_time, bulk_list)
data_wire_new = sum_mat(data_wire, wire_list)
data_wire_time_new = sum_time(data_wire_time, wire_list)

# %%
data_wire_time_new
# Out:
#        key              wire_1              wire_2 sum
# 0        1 2019-05-03 11:11:41                 NaT NaT
# 1        2 2019-05-03 11:46:10                 NaT NaT
# 2        3 2019-05-03 12:13:47                 NaT NaT
# 3        4 2019-05-03 12:48:05                 NaT NaT
# 4        5 2019-05-03 13:18:15 2019-05-03 13:32:06 NaT
# ...    ...                 ...                 ...  ..
# 3076  3237 2019-08-31 22:50:20                 NaT NaT
# 3077  3238 2019-08-31 23:38:24                 NaT NaT
# 3078  3239 2019-09-01 01:50:43                 NaT NaT
# 3079  3240 2019-09-01 03:12:02                 NaT NaT
# 3080  3241 2019-09-01 04:16:01                 NaT NaT
#
# [3081 rows x 4 columns]

# %%
data_final = data_temp.merge(data_bulk_new, how='inner', on='key')
data_final = data_final.merge(data_wire_new, how='inner', on='key')

# %%
data_final_time = data_temp.merge(data_bulk_time_new, how='inner', on='key')
data_final_time = data_final_time.merge(data_wire_time_new, how='inner', on='key')

# %%
for i in data_final.columns[3:]:
    data_final.loc[data_final_time['time'] < data_final_time[i], [i]] = 0

# %% [markdown]
# Соединили в один материалы, используемое количество которых мало. Далее присоеденили к таблицы с температурой и занулили те значения, где замер температуры происходил до использования соответсвующего материала.

# %%
data_final = data_final.merge(data_gas, how='inner', on='key')

# %%
data_final[data_final.columns[3:]] = data_final[data_final.columns[3:]].fillna(0)

# %%
data_final.head()
# Out:
#    key                time  temperature  bulk_3  bulk_4  bulk_6  bulk_12  \
# 0    1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
# 1    1 2019-05-03 11:25:53       1604.0     0.0    43.0     0.0    206.0
# 2    1 2019-05-03 11:29:11       1618.0     0.0    43.0     0.0    206.0
# 3    1 2019-05-03 11:30:01       1601.0     0.0    43.0     0.0    206.0
# 4    1 2019-05-03 11:30:39       1613.0     0.0    43.0     0.0    206.0
#
#    bulk_14  bulk_15  sum_x     wire_1  wire_2  sum_y      gas_1
# 0    150.0    154.0    0.0  60.059998     0.0    0.0  29.749986
# 1    150.0    154.0    0.0  60.059998     0.0    0.0  29.749986
# 2    150.0    154.0    0.0  60.059998     0.0    0.0  29.749986
# 3    150.0    154.0    0.0  60.059998     0.0    0.0  29.749986
# 4    150.0    154.0    0.0  60.059998     0.0    0.0  29.749986

# %% [markdown]
# Добавид газ в таблицу и заполним пропуски в материалах нулями.

# %%
data_final = data_final.loc[~(data_final[data_final.columns[3:13]] == 0).all(axis=1)]

# %% [markdown]
# Оставим только те строки, где есть хотябы одно не пустое значение в столбцах с материалами.

# %% [markdown]
# ### Создание признаков

# %%
data_arc
# Out:
#         key   arc_heating_start     arc_heating_end  active_power  \
# 0         1 2019-05-03 11:02:14 2019-05-03 11:06:02      0.976059
# 1         1 2019-05-03 11:07:28 2019-05-03 11:10:33      0.805607
# 2         1 2019-05-03 11:11:44 2019-05-03 11:14:36      0.744363
# 3         1 2019-05-03 11:18:14 2019-05-03 11:24:19      1.659363
# 4         1 2019-05-03 11:26:09 2019-05-03 11:28:37      0.692755
# ...     ...                 ...                 ...           ...
# 14871  3241 2019-09-01 03:58:58 2019-09-01 04:01:35      0.533670
# 14872  3241 2019-09-01 04:05:04 2019-09-01 04:08:04      0.676604
# 14873  3241 2019-09-01 04:16:41 2019-09-01 04:19:45      0.733899
# 14874  3241 2019-09-01 04:31:51 2019-09-01 04:32:48      0.220694
# 14875  3241 2019-09-01 04:34:47 2019-09-01 04:36:08      0.306580
#
#        reactive_power
# 0            0.687084
# 1            0.520285
# 2            0.498805
# 3            1.062669
# 4            0.414397
# ...               ...
# ...

# %%
data_arc = data_arc[data_arc['reactive_power'] > 0].copy()

# %%
data_arc['heat_sec'] = (data_arc['arc_heating_end'] - data_arc['arc_heating_start']).dt.total_seconds()
first_temp = data_final.groupby('key').first()

# %%
data_arc['apparent_power'] = np.sqrt(data_arc['active_power']**2 + data_arc['reactive_power']**2)
data_arc['power_coeff'] = data_arc['active_power'] / data_arc['apparent_power']
data_arc['work'] = data_arc['active_power'] * data_arc['heat_sec']

# %% [markdown]
# Добавим новые призанки: полную мощность, работу, время нагрева, отношение мощностей.

# %%
data_final = data_final.merge(data_arc, how='inner', on='key')

# %%
data_final.head()
# Out:
#    key                time  temperature  bulk_3  bulk_4  bulk_6  bulk_12  \
# 0    1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
# 1    1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
# 2    1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
# 3    1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
# 4    1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
#
#    bulk_14  bulk_15  sum_x  ...  sum_y      gas_1   arc_heating_start  \
# 0    150.0    154.0    0.0  ...    0.0  29.749986 2019-05-03 11:02:14
# 1    150.0    154.0    0.0  ...    0.0  29.749986 2019-05-03 11:07:28
# 2    150.0    154.0    0.0  ...    0.0  29.749986 2019-05-03 11:11:44
# 3    150.0    154.0    0.0  ...    0.0  29.749986 2019-05-03 11:18:14
# 4    150.0    154.0    0.0  ...    0.0  29.749986 2019-05-03 11:26:09
#
#       arc_heating_end active_power reactive_power  heat_sec  apparent_power  \
# ...

# %%
data_final['arc_heating_start_shift'] = data_final['arc_heating_start'].shift(-1)

data_final.dropna(axis=0, inplace=True)

# %%
data_final['key'].nunique()
# Out:
# 2423

# %%
data_final = data_final[(data_final['time'] > data_final['arc_heating_end'])&\
           (data_final['time'] < data_final['arc_heating_start_shift'])]

# %% [markdown]
# Оставим в таблице только замеры температуры после различных этапов. Уберем лишние этапы измерения температуры. Еще добавим как признак время от оконцания процесса до измерения температуры.

# %%
data_final['sec_between'] = (data_final['arc_heating_end'] - data_final['time']).dt.total_seconds()

# %%
data_final.head()
# Out:
#     key                time  temperature  bulk_3  bulk_4  bulk_6  bulk_12  \
# 2     1 2019-05-03 11:16:18       1571.0     0.0     0.0     0.0    206.0
# 8     1 2019-05-03 11:25:53       1604.0     0.0    43.0     0.0    206.0
# 24    1 2019-05-03 11:30:39       1613.0     0.0    43.0     0.0    206.0
# 27    2 2019-05-03 11:49:38       1589.0     0.0    73.0     0.0    206.0
# 40    2 2019-05-03 11:59:12       1602.0     0.0    73.0     0.0    206.0
#
#     bulk_14  bulk_15  sum_x  ...   arc_heating_start     arc_heating_end  \
# 2     150.0    154.0    0.0  ... 2019-05-03 11:11:44 2019-05-03 11:14:36
# 8     150.0    154.0    0.0  ... 2019-05-03 11:18:14 2019-05-03 11:24:19
# 24    150.0    154.0    0.0  ... 2019-05-03 11:26:09 2019-05-03 11:28:37
# 27    149.0    154.0    0.0  ... 2019-05-03 11:46:19 2019-05-03 11:48:25
# 40    149.0    154.0    0.0  ... 2019-05-03 11:49:48 2019-05-03 11:53:18
#
#     active_power  reactive_power heat_sec apparent_power  power_coeff  \
# ...

# %%
remove = data_final['key'].value_counts()
data_final = data_final[~data_final['key'].isin(remove[remove < 2].index)]

# %%
data_final = data_final[data_final['temperature']>1400]
data_final = data_final[data_final['temperature'].notna()]

# %%
data_final['key'].nunique()
# Out:
# 2206

# %%
data_final = data_final.groupby('key').last()

# %%
data_final['first_temp'] = first_temp['temperature']

# %%
data_final
# Out:
#                     time  temperature  bulk_3  bulk_4  bulk_6  bulk_12  \
# key
# 1    2019-05-03 11:30:39       1613.0     0.0    43.0     0.0    206.0
# 2    2019-05-03 11:59:12       1602.0     0.0    73.0     0.0    206.0
# 3    2019-05-03 12:34:57       1599.0     0.0    34.0     0.0    205.0
# 4    2019-05-03 12:59:25       1625.0     0.0    81.0     0.0    207.0
# 5    2019-05-03 13:36:01       1602.0     0.0    78.0     0.0    203.0
# ...                  ...          ...     ...     ...     ...      ...
# 2495 2019-08-06 00:54:42       1591.0    21.0     0.0     0.0    256.0
# 2496 2019-08-06 01:29:52       1591.0     0.0    63.0     0.0    256.0
# 2497 2019-08-06 01:53:50       1589.0     0.0    85.0     0.0    230.0
# 2498 2019-08-06 02:25:31       1594.0    90.0     0.0     0.0    206.0
# 2499 2019-08-06 03:00:28       1603.0    47.0     0.0     0.0    233.0
#
#       bulk_14  bulk_15  sum_x      wire_1  ...     arc_heating_end  \
# ...

# %% [markdown]
# Добавим среднюю температуры за предыдущие итерации партии, а для прогноза оставим только последние измерение.

# %% [markdown]
# ### Проверка мультиколлинеарности

# %%
data_final.drop(['time', 'arc_heating_end', 'arc_heating_start', 'arc_heating_start_shift'], axis=1,
               inplace=True)

# %%
plt.figure(figsize=(20,15))
correlation_mat = data_final.corr()
sns.heatmap(correlation_mat, annot = True)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Созданные признаки на основе мощностей имеют большую коллинеарность, оно и не удивительно. Оставим коэффициент полной, поскольку он включаетс в себя другие показатели.

# %%
data_final.drop(['active_power', 'reactive_power', 'work', 'heat_sec'], axis=1,
               inplace=True)

# %%
plt.figure(figsize=(20,15))
correlation_mat = data_final.corr()
sns.heatmap(correlation_mat, annot = True)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Оставим только те партии, в которых больше одного измерения.

# %%
data_final
# Out:
#       temperature  bulk_3  bulk_4  bulk_6  bulk_12  bulk_14  bulk_15  sum_x  \
# key
# 1          1613.0     0.0    43.0     0.0    206.0    150.0    154.0    0.0
# 2          1602.0     0.0    73.0     0.0    206.0    149.0    154.0    0.0
# 3          1599.0     0.0    34.0     0.0    205.0    152.0    153.0    0.0
# 4          1625.0     0.0    81.0     0.0    207.0    153.0    154.0    0.0
# 5          1602.0     0.0    78.0     0.0    203.0    151.0    152.0    0.0
# ...           ...     ...     ...     ...      ...      ...      ...    ...
# 2495       1591.0    21.0     0.0     0.0    256.0    129.0    223.0   90.0
# 2496       1591.0     0.0    63.0     0.0    256.0    129.0    226.0  122.0
# 2497       1589.0     0.0    85.0     0.0    230.0    124.0    226.0    0.0
# 2498       1594.0    90.0     0.0     0.0    206.0    129.0    207.0  101.0
# 2499       1603.0    47.0     0.0     0.0    233.0    126.0    227.0    0.0
#
# ...

# %%
data_final.dropna(axis=0, inplace=True)
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2206 entries, 1 to 2499
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   temperature     2206 non-null   float64
#  1   bulk_3          2206 non-null   float64
#  2   bulk_4          2206 non-null   float64
#  3   bulk_6          2206 non-null   float64
#  4   bulk_12         2206 non-null   float64
#  5   bulk_14         2206 non-null   float64
#  6   bulk_15         2206 non-null   float64
#  7   sum_x           2206 non-null   float64
#  8   wire_1          2206 non-null   float64
#  9   wire_2          2206 non-null   float64
#  10  sum_y           2206 non-null   float64
#  11  gas_1           2206 non-null   float64
#  12  apparent_power  2206 non-null   float64
#  13  power_coeff     2206 non-null   float64
#  14  sec_between     2206 non-null   float64
#  15  first_temp      2206 non-null   float64
# dtypes: float64(16)
# ...

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ###  Обучение

# %%
X = data_final.drop(['temperature'], axis=1)
y = data_final.temperature

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=RANDOM_STATE)

# %%
models = {
    "RandomForest" : RandomForestRegressor(random_state=RANDOM_STATE),
    "LGBM" : LGBMRegressor(random_state=RANDOM_STATE),
    'DecisionTree': DecisionTreeRegressor(random_state=RANDOM_STATE),
    #'Ridge': Ridge(random_state=RANDOM_STATE),
    'ElasticNet': ElasticNet(random_state=RANDOM_STATE),
    'Lasso': Lasso(random_state=RANDOM_STATE)
}
LR_grid = {}

Ridge_grid = {'model__alpha':[200, 230, 250, 270, 290, 300]}
Lasso_grid = {'model__alpha':[0.02, 0.024, 0.026, 0.03]}
El_grid = {"model__max_iter": [1, 5, 10],
                      "model__alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                      "model__l1_ratio": np.arange(0.0, 1.0, 0.1)}

DT_grid = {'model__max_depth': [4, 6, 8, 10],
            'model__min_samples_leaf': [1, 3, 5, 8]}

RF_grid = {'model__n_estimators': [20, 40, 80, 100, 150, 200, 250],
        'model__max_depth': [10, 20, 40, 50, 100, 150]}

boost_grid = {'model__n_estimators': [50, 100, 150, 200, 250],
        'model__max_depth': [8, 16, 32, 64, 128],
        'model__learning_rate': [0.001, 0.01, 0.1]}

grid = {
    "RandomForest" : RF_grid,
    "LGBM" : boost_grid,
    "DecisionTree" : DT_grid,
    'Ridge': Ridge_grid,
    'Lasso': Lasso_grid,
    'ElasticNet': El_grid
}

# %%
def pipeline(X_train, y_train):
    i=0
    clf_best_params=models.copy()
    valid_scores=pd.DataFrame({'Model':models.keys(), 'MAE': np.zeros(len(models)), 'Training time': np.zeros(len(models))})
    for key, model in models.items():
        pipeline = Pipeline([( "scaler" , StandardScaler()),('model', model)])
        clf = RandomizedSearchCV(estimator=pipeline, param_distributions=grid[key], n_jobs=-1, cv=3,
                                 scoring='neg_mean_absolute_error', verbose=2)
        start = time.time()

        clf.fit(X_train, y_train)
        valid_scores.iloc[i,1]=clf.best_score_

        clf_best_params[key]=clf.best_params_

        stop = time.time()
        valid_scores.iloc[i,2]=np.round((stop - start)/60, 2)

        print('Model:', key)
        print('Training time (mins):', valid_scores.iloc[i,2])
        print('')
        i+=1
    return valid_scores, clf_best_params, clf.best_estimator_

# %%
valid_scores, best_params, best_estimator =  pipeline(X_train, y_train)

# %%
valid_scores
# Out:
#           Model       MAE  Training time
# 0  RandomForest -6.613687           0.54
# 1          LGBM -6.550217          12.92
# 2  DecisionTree -7.239394           0.01
# 3    ElasticNet -6.587439           0.06
# 4         Lasso -6.601554           0.02

# %%
best_params
# Out:
# {'RandomForest': {'model__n_estimators': 200, 'model__max_depth': 10},
#  'LGBM': {'model__n_estimators': 250,
#   'model__max_depth': 64,
#   'model__learning_rate': 0.01},
#  'DecisionTree': {'model__min_samples_leaf': 3, 'model__max_depth': 4},
#  'ElasticNet': {'model__max_iter': 5,
#   'model__l1_ratio': 0.5,
#   'model__alpha': 0.1},
#  'Lasso': {'model__alpha': 0.03}}

# %% [markdown]
# На обучении наилучшей моделью является LGBM ее и возьмем для тестирования.

# %% [markdown]
# ### Тестирование

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
clf = LGBMRegressor(n_estimators=50, max_depth=8, learning_rate=0.1, random_state=RANDOM_STATE)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 6.559521159193425

# %%
clf_d = DummyRegressor(strategy="mean")
clf_d.fit(X_train, y_train)
y_pred_d = clf_d.predict(X_test)
mean_absolute_error(y_test, y_pred_d)
# Out:
# 8.196644498186213

# %%
feature_importance = clf.feature_importances_
sorted_idx = np.argsort(feature_importance)
fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X.columns)[sorted_idx])
plt.title('Feature Importance');

# %% [markdown]
# # Вывод

# %% [markdown]
# В проекте стояла задача по поиску оптимальной модели для предсказания темппературы сплава. При анализе данных были выявлены некоторые аномалии и выбросы в данных. Например большое количество нулевых значений в используемых материалах. Такие выбросы возможно связаны со сбоями в оборудовании. Так же стоит отметить некоторые нестыковки в тестовой выборке. Присутвовали последовательные измерения температуры, неразделенные никакими процессами. В финальную выборку вошло 2206 набюдений, где у каждой партии хотябы два замера температуры. Рассмотрнео пять моделей машинного обучения. По рассчету финальной оценки MAE, выбрана модель LGBM. Качество данной модели составило 6.56, что ниже заданного бейзлайна. Наиболее значимыми признаками для оценки температуры являются:
# - Полная мощность
# - Начальная температура партии
# - Коэффициент мощности

# %% [markdown]
# ## Отчет

# %% [markdown]
# 1. В целом все пункты плана были выполнены. Данные были подготовлены: выбросы удалены, созданы новые признаки. Далее выполнен поиск наилучшей модели и ее гиперпараметров. После расммотрена важность факторов.
#
# 2. Основная трудность заключалась в последовательном рассмотрении производственного цикла. Малое количество данных о используемых материалах сильно сказывается на объеме данных, анализируемых моделью. Так от большого количества итераций в партиях пришлось избавиться из-за нехватки данных.
#
# 3. Ключевые шаги:
#  - Анализ данных:
#      - Основным шагом здесь является не рассмотрение пропусков и аномали, а понимание процесса производства.
#  - Подготовка данных
#      - Создание сводной таблицы
#      - Создание новых признаков
#  - Анализ моделей
#      - Обучени и поиск гиперпарметров
#      - Анализ факторов важности
#
# 4. **Лучшая модель - LGBMRegressor. MAE = 6.56**
# - Параметры модели:
#     - *learning_rate = 0.1*
#     - *max_depth = 8*
#     - *n_estimators = 50*
# - Признаки используемые в обучении:
#     - *bulk (3,4,6,14,15)* - объем сыпучих материалов. Были убраны итерации в паотиях, где отсутвовали данные признаки.
#     - *sum_x* - объем сыпучих материалов, а именно сумма материалов с малым количеством наблюдений.
#     - *gas* - данные о продувке газом.
#     - *first_temp* - замер температуры в партии, до начала производственного цикла.
#     - *wire (1,2)* - объем проволочных материалов. Обработка аналогична сыпучим матреиалам.
#     - *sum_y* - объем проволочных материалов, а именно сумма материалов с малым количеством наблюдений.
#     - *apparent_power* - Полная мощность, рассчитанная по формуле $S=\sqrt{P^2+Q^2}$
#     - *sec_between* - время между окончанием процесса и змерением температуры
#     - *power_coeff*	- клэффициент мощности $Pf=P/S$
